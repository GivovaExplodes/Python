# %% [markdown]
# Michael Byrnes (20229313)
#
# My question is the association between education and balance

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./bank.csv')
df.head(5)
# Out:
#     age          job   marital  education default  balance housing loan  \
# 0  32.0   technician    single   tertiary      no      392     yes   no
# 1  39.0   technician  divorced  secondary      no      688     yes  yes
# 2  59.0      retired   married  secondary      no     1035     yes  yes
# 3  47.0  blue-collar   married  secondary      no      398     yes  yes
# 4  54.0      retired   married  secondary      no     1004     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome  \
# 0  cellular    1   apr       957         2    131         2  failure
# 1  cellular    1   apr       233         2    133         1  failure
# 2  cellular    1   apr       126         2    239         1  failure
# 3  cellular    1   apr       274         1    238         2  failure
# 4  cellular    1   apr       479         1    307         1  failure
#
#   subscribed
# 0         no
# 1         no
# 2         no
# 3         no
# 4         no

# %% [markdown]
# Output:
# ![image.png](data:image/png;base64,...)

# %%
df.tail(5)
# Out:
#        age           job  marital  education default  balance housing loan  \
# 1995  20.0       student   single        NaN      no     2785      no   no
# 1996  28.0        admin.   single  secondary      no      127      no   no
# 1997  81.0       retired  married    primary      no     1154      no   no
# 1998  46.0      services  married    primary      no     4343     yes   no
# 1999  40.0  entrepreneur  married  secondary      no     6403      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 1995   cellular   16   sep       327         2     -1         0      NaN
# 1996   cellular   16   sep      1334         2     -1         0      NaN
# 1997  telephone   17   sep       231         1     -1         0      NaN
# 1998        NaN   20   sep       185         1     -1         0      NaN
# 1999   cellular   22   sep       208         2     -1         0      NaN
#
#      subscribed
# 1995        yes
# 1996        yes
# 1997        yes
# ...

# %% [markdown]
# Output:
# ![image.png](data:image/png;base64,...)

# %%
df.describe()
# Out:
#                age       balance          day     duration     campaign  \
# count  1988.000000   2000.000000  2000.000000  2000.000000  2000.000000
# mean     41.753018   1413.663500    13.851500   292.020500     1.909500
# std      12.724358   3131.224213     9.712189   221.557295     1.378862
# min      18.000000   -980.000000     1.000000     7.000000     1.000000
# 25%      32.000000    201.500000     5.000000   146.000000     1.000000
# 50%      38.000000    551.000000    12.000000   236.000000     1.000000
# 75%      50.000000   1644.500000    23.000000   379.000000     2.000000
# max      93.000000  81204.000000    31.000000  1823.000000    11.000000
#
#              pdays     previous
# count  2000.000000  2000.000000
# mean    167.896000     2.561500
# std     131.754126     3.400735
# min      -1.000000     0.000000
# 25%      75.750000     1.000000
# 50%     182.000000     2.000000
# 75%     251.000000     3.000000
# max     854.000000    55.000000

# %% [markdown]
# Output:
#
# ![image.png](data:image/png;base64,...)

# %%
sns.heatmap(df.corr());
# Out:
# <ipython-input-5-f044f2f5ad42>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr());

# %% [markdown]
# Output:
#
# ![image.png](data:image/png;base64,...)

# %%
sns.pairplot(data=df[['age','balance','duration','campaign']].dropna())
plt.show()

# %% [markdown]
# Output:
#
# ![image.png](data:image/png;base64,...)

# %%
sns.violinplot(x=df['age'], orient='v', width=0.5)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:1608: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))

# %% [markdown]
# Output:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This shows that the most frequent age for this study was between 30 - 40 years old

# %%
sns.swarmplot(x=df['duration'], orient='h')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3398: UserWarning: 49.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Output:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This shows that the duration of most of the data is 500 or less

# %%
df['education'].value_counts()
# Out:
# secondary    995
# tertiary     684
# primary      217
# Name: education, dtype: int64

# %% [markdown]
# Output:
#
# ![image.png](data:image/png;base64,...)

# %%
sns.stripplot(data=df, x="education", y="balance")
# Out:
# <Axes: xlabel='education', ylabel='balance'>

# %% [markdown]
# Output:
#
# ![image.png](data:image/png;base64,...)

# %%
df.boxplot(column='balance', by='education')
plt.title('Box plot of balance grouped by education')
plt.suptitle("")
plt.show()

# %% [markdown]
# Output:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This Box Plot shows that there is no substantial difference between the mean balance of secondary & tertiary education but while the highest balance belongs to secondary, tertiary has more higher balances past the median.
